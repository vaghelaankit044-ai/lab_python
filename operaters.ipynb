# %%
x=10
print(x)
# Out:
# 10

# %%
a=5
print(-a)
# Out:
# -5

# %%
p=10
q=5
print(p>q)
print(p==q)
# Out:
# True
# False

# %%
a=5
b=3
print(a&b)
print(a/b)
# Out:
# 1
# 1.6666666666666667

# %%
numbers=(1,2,3,4,5,6)
print(2 in numbers)
print(5 not in numbers)
# Out:
# True
# False

# %%
x=10
y=10
print(x/y)#o/p true
print(x is not y)#o/p false
# Out:
# 1.0
# False
