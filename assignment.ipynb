# %%
x="welcome"
print(x)
# Out:
# welcome

# %%
print("rajesh kumar")
print("\tflatno.101,sushine apartments")
print("\trajkot")
print("\tpincode:360004")
print("\tindia")
# Out:
# rajesh kumar
# 	flatno.101,sushine apartments
# 	rajkot
# 	pincode:360004
# 	india

# %%
a=150
b=120.50
print("addition",a+b)
print("subtraction:",a-b)
print("multiplication:",a*b)
print("division:",a/b)
# Out:
# addition 270.5
# subtraction: 29.5
# multiplication: 18075.0
# division: 1.2448132780082988

# %%
radius=float(input("enter radius:"))
pi=3.14
area=pi*radius*radius
circumference=2*pi*radius
print("area of circle:"area)
print("circumference of circle:", circumference)
# Out:
# enter radius: 20

# %%
p=float(input("enter principal amount:"))
r=float(input("enter rate of interest:"))
t=float(input("enter time (in years):"))
sl=(p*r*t)/100
print("simple interest:",sl)
# Out:
# enter principal amount: 3
# enter rate of interest: 4
# enter time (in years): 6
# simple interest: 0.72

# %%
length=float(input("enter length:"))
width=float(input("enter width:"))
perimeter=2*(length+width)
print("perimeter of rectangle:",perimeter)
# Out:
# enter length: 10
# enter width: 15
# perimeter of rectangle: 50.0

# %%
length=float(input("enter length:"))
width=float(input("enter width:"))
area=length*width
perimeter=2*(length+width)
print("area of rectangle:",area)
print("perimeter of rectangle:",perimeter)
# Out:
# enter length: 10
# enter width: 20
# area of rectangle: 200.0
# perimeter of rectangle: 60.0

# %%
a=float(input("enter side a:"))
b=float (input("enter side b:"))
c=float(input("enter side c:"))
perimeter=a+b+c
print("perimeter of triangle:",perimeter)
# Out:
# enter side a: 50
# enter side b: 52
# enter side c: 65
# perimeter of triangle: 167.0

# %% [markdown]
#  side=float(input("enter side:"))
# area=side*side
# perimeter=4*side
# print("area of square:",area)
# print("perimeter of square:",perimeter)

# %%
side=float(input("ent))
