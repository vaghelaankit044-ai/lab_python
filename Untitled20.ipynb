# %%
x="hello"
print(x)
# Out:
# hello

# %%
x=20
print(x)
# Out:
# 20

# %%
x=b"hello"
print(x)
# Out:
# b'hello'

# %%
x=range(6)
print(x)
# Out:
# range(0, 6)

# %%
x=("apple","banana","cherry")
print(x)
# Out:
# ('apple', 'banana', 'cherry')

# %%
x=("apple","bananaa","cherry")
print(x)
# Out:
# ('apple', 'bananaa', 'cherry')

# %%
x=("apple","banana","cherry")
